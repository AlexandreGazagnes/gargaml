# %%
cd  ..
# Out:
# /home/alex/gargaml

# %%
from gargaml import *
# Out:
# WARNING:root:path is /home/alex/gargaml

# %%
df = Data.make.random(len_=10_000)
df = df + 10

# %%
df["d"] = np.log1p(df.c)

# %%
Gargaml.eda.study.corr(df, figsize=3)
# Out:
#        a     b    c d
# a
# b  -0.02
# c   0.06  0.06
# d   0.06  0.06  1.0

# %%
pca = Gargaml.eda.pca(df)
pca.variance()
# Out:
#       variance  variance_cum
# PC_1      0.50          0.50
# PC_2      0.25          0.76
# PC_3      0.24          1.00
# PC_4      0.00          1.00

# %%
pca.pcs()
# Out:
#    PC_1  PC_2  PC_3  PC_4
# a  0.09  0.70 -0.71  0.00
# b  0.08 -0.71 -0.70 -0.00
# c  0.70 -0.00  0.08  0.71
# d  0.70 -0.00  0.08 -0.71

# %%
df.corr()
# Out:
#           a         b         c
# a  1.000000  0.035120 -0.055599
# b  0.035120  1.000000 -0.024843
# c -0.055599 -0.024843  1.000000

# %%
pca = Gargaml.eda.pca(df)

# %%
pca.pcs()
# Out:
#    PC_1  PC_2  PC_3
# a  0.64 -0.20  0.74
# b  0.48  0.86 -0.17
# c -0.60  0.46  0.65

# %%
pca.variance()
# Out:
#       variance  variance_cum
# PC_1      0.36          0.36
# PC_2      0.33          0.69
# PC_3      0.31          1.00

# %%
df.b = 2 * df.a + 3

# %%
df.c = df.b * (df.a + 1)

# %%
df
# Out:
#             a         b         c
# 0    0.514322  4.028644  6.100665
# 1    0.782671  4.565342  8.138503
# 2    0.347554  3.695108  4.979357
# 3    0.852364  4.704727  8.714865
# 4    0.426894  3.853789  5.498949
# ..        ...       ...       ...
# 995  0.114665  3.229329  3.599619
# 996  0.428082  3.856165  5.506920
# 997  0.173263  3.346526  3.926354
# 998  0.416427  3.832854  5.428958
# 999  0.567951  4.135901  6.484889
#
# [1000 rows x 3 columns]

# %%
df.corr()
# Out:
#           a         b         c
# a  1.000000  1.000000  0.997265
# b  1.000000  1.000000  0.997265
# c  0.997265  0.997265  1.000000

# %%
pca = Gargaml.eda.pca(df)

# %%
pca.pcs()
# Out:
#    PC_1  PC_2  PC_3
# a  0.58 -0.41  0.71
# b  0.58 -0.41 -0.71
# c  0.58  0.82 -0.00

# %%
pca.variance()
# Out:
#       variance  variance_cum
# PC_1       1.0           1.0
# PC_2       0.0           1.0
# PC_3       0.0           1.0
