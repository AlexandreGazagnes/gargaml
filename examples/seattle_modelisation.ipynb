# %% [markdown]
# # 1 Preliminaries

# %% [markdown]
# ## 1.0 Context

# %% [markdown]
# * About Seattle dataframe
# * Small démo of gargaml usage

# %% [markdown]
# ## 1.1 System

# %%
# !pwd
# Out:
# /home/alex/gargaml/examples

# %%
cd ..
# Out:
# /home/alex/gargaml

# %%
# !pwd
# Out:
# /home/alex/gargaml

# %%
# !ls
# Out:
# CHANGELOG.md  examples	pyproject.toml	  results   utils
# docs	      gargaml	README.md	  setup.py
# env	      LICENSE	requirements.txt  tests

# %%
# !uname -a
# Out:
# Linux asus2023 6.2.0-20-generic #20-Ubuntu SMP PREEMPT_DYNAMIC Thu Apr  6 07:48:48 UTC 2023 x86_64 x86_64 x86_64 GNU/Linux

# %%
# !which python
# Out:
# /home/alex/gargaml/env/bin/python

# %% [markdown]
# ## 1.2 Install

# %%
# if needed :

# !pip install -r requirements.txt

# %%
# if needed :

# !pip freeze > requirements.freeze

# %% [markdown]
# ## 1.3 Import

# %%
# in one line :

from gargaml import *
# Out:
# WARNING:root:path is /home/alex/gargaml

# %%
# or manually :

# import random, os, sys, warnings, datetime, time, logging
# from IPython.display import display
# # pandarallel

# import pandas as pd
# import numpy as np

# import scipy as sp
# import scipy.stats as st

# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go
# import plotly.io as pio
# import missingno as msno


# from sklearn.base import *

# from sklearn.feature_selection import *
# from sklearn.feature_extraction import *
# from sklearn.preprocessing import *
# from sklearn.pipeline import *
# from sklearn.covariance import *
# from sklearn.decomposition import *
# from sklearn.model_selection import *
# from sklearn.impute import *
# from sklearn.metrics import *
# from sklearn.cluster import *
# from sklearn.compose import *

# from sklearn.dummy import *
# from sklearn.linear_model import *
# from sklearn.svm import *
# from sklearn.neighbors import *
# from sklearn.ensemble import *


# from imblearn.under_sampling import RandomUnderSampler
# from imblearn.pipeline import Pipeline

# from xgboost import XGBRegressor, XGBRFRegressor

# ...

# %% [markdown]
# ## 1.4 Data

# %%
# all datasets avialable :

Data.load.list_all
# Out:
# ['ames',
#  'boston',
#  'fashion',
#  'food',
#  'house',
#  'hr',
#  'iris',
#  'mnist',
#  'seattle',
#  'titanic',
#  'wine']

# %%
# seattle 2016 :

df = Data.load.seattle(year="2016")
df.head(2)
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType
# 0              1      2016  NonResidential               Hotel  \
# 1              2      2016  NonResidential               Hotel
#
#            PropertyName          Address     City State  ZipCode
# 0  Mayflower park hotel    405 Olive way  Seattle    WA  98101.0  \
# 1       Paramount Hotel  724 Pine street  Seattle    WA  98101.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)
# 0                    0659000030  ...      1.156514e+06         3946027.0  \
# 1                    0659000220  ...      9.504252e+05         3242851.0
#
#    NaturalGas(therms)  NaturalGas(kBtu)  DefaultData  Comments
# 0         12764.52930         1276453.0        False       NaN  \
# 1         51450.81641         5145082.0        False       NaN
#
#    ComplianceStatus  Outlier  TotalGHGEmissions  GHGEmissionsIntensity
# 0         Compliant      NaN             249.98                   2.83
# 1         Compliant      NaN             295.86                   2.86
#
# [2 rows x 46 columns]

# %% [markdown]
# ## 1.5 Options and Graphics

# %%
# boot seaborn  :

sns.set()

# %%
# usefull consts :

DISPLAY = True
FRAC = 1.0
LAZY = False

# %%
# warning messages :

warnings.filterwarnings(action="once")

# or :
# warnings.filterwarnings('ignore')

# %%
# if png and not fancy graphs with plotly :

# pio.renderers.default = "png"

# %% [markdown]
# ## 1.6 Third parties and utils

# %%
# placeholder

# %%
results = ML.results("test")

# %% [markdown]
# ## 1.7 Functions and class

# %%
# placeholder

# %% [markdown]
# # 2 First Tour

# %% [markdown]
# ## 2.0 Pre-cleaning

# %%
# about columns quality :

df.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'DefaultData', 'Comments', 'ComplianceStatus',
#        'Outlier', 'TotalGHGEmissions', 'GHGEmissionsIntensity'],
#       dtype='object')

# %%
# clean columns :


def clean(txt):
    txt = txt.lower().strip()
    replace = [
        ("(s)", ""),
        ("(", "_"),
        (")", ""),
        ("/", "_"),
        ("__", "_"),
    ]

    for k, v in replace:
        txt = txt.replace(k, v)

    txt = txt.lower().strip()
    return txt


df.columns = map(clean, df.columns)
df.columns
# Out:
# Index(['osebuildingid', 'datayear', 'buildingtype', 'primarypropertytype',
#        'propertyname', 'address', 'city', 'state', 'zipcode',
#        'taxparcelidentificationnumber', 'councildistrictcode', 'neighborhood',
#        'latitude', 'longitude', 'yearbuilt', 'numberofbuildings',
#        'numberoffloors', 'propertygfatotal', 'propertygfaparking',
#        'propertygfabuilding', 'listofallpropertyusetypes',
#        'largestpropertyusetype', 'largestpropertyusetypegfa',
#        'secondlargestpropertyusetype', 'secondlargestpropertyusetypegfa',
#        'thirdlargestpropertyusetype', 'thirdlargestpropertyusetypegfa',
#        'yearsenergystarcertified', 'energystarscore', 'siteeui_kbtu_sf',
#        'siteeuiwn_kbtu_sf', 'sourceeui_kbtu_sf', 'sourceeuiwn_kbtu_sf',
#        'siteenergyuse_kbtu', 'siteenergyusewn_kbtu', 'steamuse_kbtu',
#        'electricity_kwh', 'electricity_kbtu', 'naturalgas_therms',
#        'naturalgas_kbtu', 'defaultdata', 'comments', 'compliancestatus',
#        'outlier', 'totalghgemissions', 'ghgemissionsintensity'],
#       dtype='object')

# %%
# recast osebuildingid :

df.osebuildingid = df.osebuildingid.astype(str)
df.head(2)
# Out:
#   osebuildingid  datayear    buildingtype primarypropertytype
# 0             1      2016  NonResidential               Hotel  \
# 1             2      2016  NonResidential               Hotel
#
#            propertyname          address     city state  zipcode
# 0  Mayflower park hotel    405 Olive way  Seattle    WA  98101.0  \
# 1       Paramount Hotel  724 Pine street  Seattle    WA  98101.0
#
#   taxparcelidentificationnumber  ...  electricity_kwh electricity_kbtu
# 0                    0659000030  ...     1.156514e+06        3946027.0  \
# 1                    0659000220  ...     9.504252e+05        3242851.0
#
#    naturalgas_therms  naturalgas_kbtu  defaultdata  comments
# 0        12764.52930        1276453.0        False       NaN  \
# 1        51450.81641        5145082.0        False       NaN
#
#    compliancestatus  outlier  totalghgemissions  ghgemissionsintensity
# 0         Compliant      NaN             249.98                   2.83
# 1         Compliant      NaN             295.86                   2.86
#
# [2 rows x 46 columns]

# %%
df.steamuse_kbtu = df.steamuse_kbtu.apply(lambda i: i > 0).astype(int)
df.electricity_kbtu = df.electricity_kbtu.apply(lambda i: i > 0).astype(int)
df.naturalgas_kbtu = df.naturalgas_kbtu.apply(lambda i: i > 0).astype(int)

# %%
# select columns for faster and better analysis


cols = [
    "primarypropertytype",
    "neighborhood",
    "latitude",
    "longitude",
    "yearbuilt",
    "numberofbuildings",
    "numberoffloors",
    "propertygfaparking",
    "propertygfabuilding",
    "energystarscore",
    "siteenergyuse_kbtu",
    "steamuse_kbtu",
    "electricity_kbtu",
    "naturalgas_kbtu",
]


df = df.loc[:, cols]
df.head(3)
# Out:
#   primarypropertytype neighborhood  latitude  longitude  yearbuilt
# 0               Hotel     DOWNTOWN  47.61220 -122.33799       1927  \
# 1               Hotel     DOWNTOWN  47.61317 -122.33393       1996
# 2               Hotel     DOWNTOWN  47.61393 -122.33810       1969
#
#    numberofbuildings  numberoffloors  propertygfaparking  propertygfabuilding
# 0                1.0              12                   0                88434  \
# 1                1.0              11               15064                88502
# 2                1.0              41              196718               759392
#
#    energystarscore  siteenergyuse_kbtu  steamuse_kbtu  electricity_kbtu
# 0             60.0           7226362.5              1                 1  \
# 1             61.0           8387933.0              0                 1
# 2             43.0          72587024.0              1                 1
#
#    naturalgas_kbtu
# 0                1
# 1                1
# 2                1

# %%
for c in df.select_dtypes(object):
    df[c] = df[c].str.lower()

# %%
df = df.loc[df.propertygfabuilding.notna()]
df = df.loc[df.propertygfabuilding > 1, :]

df = df.loc[df.siteenergyuse_kbtu.notna()]
df = df.loc[df.siteenergyuse_kbtu > 1, :]

df
# Out:
#      primarypropertytype           neighborhood  latitude  longitude
# 0                  hotel               downtown  47.61220 -122.33799  \
# 1                  hotel               downtown  47.61317 -122.33393
# 2                  hotel               downtown  47.61393 -122.33810
# 3                  hotel               downtown  47.61412 -122.33664
# 4                  hotel               downtown  47.61375 -122.34047
# ...                  ...                    ...       ...        ...
# 3371              office       greater duwamish  47.56722 -122.31154
# 3372               other               downtown  47.59625 -122.32283
# 3373               other  magnolia / queen anne  47.63644 -122.35784
# 3374  mixed use property       greater duwamish  47.52832 -122.32431
# 3375  mixed use property       greater duwamish  47.53939 -122.29536
#
#       yearbuilt  numberofbuildings  numberoffloors  propertygfaparking
# 0          1927                1.0              12                   0  \
# 1          1996                1.0              11               15064
# 2          1969                1.0              41              196718
# 3          1926                1.0              10                   0
# 4          1980                1.0              18               62000
# ...         ...                ...             ...                 ...
# 3371       1990                1.0               1                   0
# 3372       2004                1.0               1                   0
# 3373       1974                1.0               1                   0
# 3374       1989                1.0               1                   0
# 3375       1938                1.0               1                   0
#
#       propertygfabuilding  energystarscore  siteenergyuse_kbtu  steamuse_kbtu
# 0                   88434             60.0        7.226362e+06              1  \
# 1                   88502             61.0        8.387933e+06              0
# 2                  759392             43.0        7.258702e+07              1
# 3                   61320             56.0        6.794584e+06              1
# 4                  113580             75.0        1.417261e+07              0
# ...                   ...              ...                 ...            ...
# 3371                12294             46.0        8.497457e+05              0
# 3372                16000              NaN        9.502762e+05              0
# 3373                13157              NaN        5.765898e+06              0
# 3374                14101              NaN        7.194712e+05              0
# 3375                18258              NaN        1.152896e+06              0
#
#       electricity_kbtu  naturalgas_kbtu
# 0                    1                1
# 1                    1                1
# 2                    1                1
# 3                    1                1
# 4                    1                1
# ...                ...              ...
# 3371                 1                1
# 3372                 1                1
# 3373                 1                1
# 3374                 1                1
# 3375                 1                1
#
# [3353 rows x 14 columns]

# %%
df.numberofbuildings = df.numberofbuildings.fillna(1)
df.numberoffloors = df.numberoffloors.fillna(1)

# df.numberofbuildings = df.numberofbuildings.astype(int)
# df.numberoffloors = df.numberoffloors.astype(int)

df.numberofbuildings = df.numberofbuildings.replace({0: 1})
df.numberoffloors = df.numberoffloors.replace({0: 1})

# df.numberofbuildings = df.numberofbuildings.apply(lambda i : i if i>=1 else 1)
# df.numberoffloors = df.numberoffloors.apply(lambda i : i if i>=1 else 1)

df.propertygfaparking = df.propertygfaparking.apply(lambda i: i > 0).astype(int)
df["bool_energystarscore"] = df.energystarscore.isna().astype(int)

df["gfaperfloor"] = df.propertygfabuilding / df.numberoffloors
df["gfaperbuilding"] = df.propertygfabuilding / df.numberofbuildings

df.describe()
# Out:
#           latitude    longitude    yearbuilt  numberofbuildings
# count  3353.000000  3353.000000  3353.000000        3353.000000  \
# mean     47.623913  -122.334796  1968.569937           1.134805
# std       0.047676     0.027158    33.135785           2.105019
# min      47.499170  -122.414250  1900.000000           1.000000
# 25%      47.599850  -122.350560  1948.000000           1.000000
# 50%      47.618610  -122.332490  1975.000000           1.000000
# 75%      47.657010  -122.319500  1997.000000           1.000000
# max      47.733870  -122.220966  2015.000000         111.000000
#
#        numberoffloors  propertygfaparking  propertygfabuilding
# count     3353.000000         3353.000000         3.353000e+03  \
# mean         4.729198            0.150015         8.660534e+04
# std          5.505425            0.357139         2.073827e+05
# min          1.000000            0.000000         3.636000e+03
# 25%          2.000000            0.000000         2.769000e+04
# 50%          4.000000            0.000000         4.316200e+04
# 75%          5.000000            0.000000         8.438500e+04
# max         99.000000            1.000000         9.320156e+06
#
#        energystarscore  siteenergyuse_kbtu  steamuse_kbtu  electricity_kbtu
# count      2532.000000        3.353000e+03    3353.000000       3353.000000  \
# mean         67.906003        5.432676e+06       0.038771          0.997614
# std          26.871011        2.166494e+07       0.193078          0.048795
# min           1.000000        1.340900e+04       0.000000          0.000000
# 25%          53.000000        9.353967e+05       0.000000          1.000000
# 50%          75.000000        1.813404e+06       0.000000          1.000000
# 75%          90.000000        4.233753e+06       0.000000          1.000000
# max         100.000000        8.739237e+08       1.000000          1.000000
#
#        naturalgas_kbtu  bool_energystarscore   gfaperfloor  gfaperbuilding
# count      3353.000000           3353.000000  3.353000e+03    3.353000e+03
# mean          0.627796              0.244855  2.623625e+04    7.990718e+04
# std           0.483464              0.430066  1.665853e+05    1.246947e+05
# min           0.000000              0.000000  2.216970e+02    3.636000e+03
# 25%           0.000000              0.000000  8.334833e+03    2.714000e+04
# 50%           1.000000              0.000000  1.325500e+04    4.183400e+04
# 75%           1.000000              0.000000  2.475050e+04    7.995700e+04
# max           1.000000              1.000000  9.320156e+06    2.200000e+06

# %%
# df.primarypropertytype.value_counts()
df.primarypropertytype = df.primarypropertytype.replace(
    {"office": "small- and mid-sized office"}
)
df.primarypropertytype.value_counts()
# Out:
# primarypropertytype
# low-rise multifamily           983
# mid-rise multifamily           564
# small- and mid-sized office    295
# other                          253
# warehouse                      187
# large office                   173
# mixed use property             132
# k-12 school                    125
# high-rise multifamily          105
# retail store                    91
# hotel                           77
# worship facility                71
# distribution center             53
# senior care community           45
# supermarket / grocery store     40
# medical office                  39
# self-storage facility           28
# university                      25
# residence hall                  23
# refrigerated warehouse          12
# restaurant                      12
# hospital                        10
# laboratory                      10
# Name: count, dtype: int64

# %% [markdown]
# ## 2.1 Display

# %%
# display df :

EDA.first_tour.display(df)
# Out:
# ----HEAD ---- primarypropertytype neighborhood  latitude  longitude
# 0                           hotel     downtown  47.61220 -122.33799  \
# 1                           hotel     downtown  47.61317 -122.33393
# 2                           hotel     downtown  47.61393 -122.33810
# 3                           hotel     downtown  47.61412 -122.33664
# 4                           hotel     downtown  47.61375 -122.34047
#
# ----HEAD ----  yearbuilt  numberofbuildings  numberoffloors
# 0                   1927                1.0              12  \
# 1                   1996                1.0              11
# 2                   1969                1.0              41
# 3                   1926                1.0              10
# 4                   1980                1.0              18
#
# ----HEAD ----  propertygfaparking  propertygfabuilding  energystarscore
# 0                               0                88434             60.0  \
# 1                               1                88502             61.0
# 2                               1               759392             43.0
# 3                               0                61320             56.0
# 4                               1               113580             75.0
#
# ----HEAD ----  siteenergyuse_kbtu  steamuse_kbtu  electricity_kbtu
# 0                       7226362.5              1                 1  \
# 1                       8387933.0              0                 1
# 2                      72587024.0              1                 1
# 3                       6794584.0              1                 1
# 4                      14172606.0              0                 1
#
# ----HEAD ----  naturalgas_kbtu  bool_energystarscore   gfaperfloor
# 0                            1                     0   7369.500000  \
# 1                            1                     0   8045.636364
# 2                            1                     0  18521.756098
# 3                            1                     0   6132.000000
# 4                            1                     0   6310.000000
#
# ----HEAD ----  gfaperbuilding
# 0                     88434.0
# 1                     88502.0
# 2                    759392.0
# 3                     61320.0
# 4                    113580.0
# ----SAMP ----          primarypropertytype           neighborhood  latitude
# 948                   low-rise multifamily                ballard  47.66965  \
# 3013                  mid-rise multifamily                   east  47.61621
# 2250                  mid-rise multifamily                ballard  47.67624
# 3132           small- and mid-sized office              northeast  47.68254
# 515            small- and mid-sized office  magnolia / queen anne  47.63156
# 1999                             warehouse       greater duwamish  47.57833
# 2859                  low-rise multifamily                central  47.60136
# 611                           large office               downtown  47.60214
# 1852                  low-rise multifamily  magnolia / queen anne  47.62782
# 1854                  low-rise multifamily  magnolia / queen anne  47.62862
#
# ----SAMP ----  longitude  yearbuilt  numberofbuildings  numberoffloors
# 948           -122.39489       1975                1.0               4  \
# 3013          -122.32241       1940                1.0               5
# 2250          -122.40974       1968                1.0               7
# 3132          -122.26299       1960                1.0               1
# 515           -122.37551       1937                1.0               2
# 1999          -122.32563       1945                1.0               1
# 2859          -122.31248       2002                1.0               4
# 611           -122.32726       2009                1.0              17
# 1852          -122.36583       1907                1.0               4
# 1854          -122.36827       1907                1.0               4
#
# ----SAMP ----  propertygfaparking  propertygfabuilding  energystarscore
# 948                             0                30948             91.0  \
# 3013                            0                50356             99.0
# 2250                            0               239054             48.0
# 3132                            0                21931             32.0
# 515                             0                61929             59.0
# 1999                            0                22972             12.0
# 2859                            0                29808             80.0
# 611                             1               275166             91.0
# 1852                            0                38407             57.0
# 1854                            0                34498            100.0
#
# ----SAMP ----  siteenergyuse_kbtu  steamuse_kbtu  electricity_kbtu
# 948                  6.233223e+05              0                 1  \
# 3013                 2.503804e+06              0                 1
# 2250                 1.221342e+07              0                 1
# 3132                 3.947209e+06              0                 1
# 515                  2.203026e+06              0                 1
# 1999                 4.954810e+05              0                 1
# 2859                 9.753270e+05              0                 1
# 611                  1.363114e+07              0                 1
# 1852                 1.208169e+06              0                 1
# 1854                 9.106392e+05              0                 1
#
# ----SAMP ----  naturalgas_kbtu  bool_energystarscore   gfaperfloor
# 948                          0                     0   7737.000000  \
# 3013                         1                     0  10071.200000
# 2250                         1                     0  34150.571429
# 3132                         1                     0  21931.000000
# 515                          1                     0  30964.500000
# 1999                         0                     0  22972.000000
# 2859                         1                     0   7452.000000
# 611                          0                     0  16186.235294
# 1852                         0                     0   9601.750000
# 1854                         1                     0   8624.500000
#
# ----SAMP ----  gfaperbuilding
# 948                   30948.0
# 3013                  50356.0
# 2250                 239054.0
# 3132                  21931.0
# 515                   61929.0
# 1999                  22972.0
# 2859                  29808.0
# 611                  275166.0
# 1852                  38407.0
# 1854                  34498.0
# ----TAIL ----          primarypropertytype           neighborhood  latitude
# 3371           small- and mid-sized office       greater duwamish  47.56722  \
# 3372                                 other               downtown  47.59625
# 3373                                 other  magnolia / queen anne  47.63644
# 3374                    mixed use property       greater duwamish  47.52832
# 3375                    mixed use property       greater duwamish  47.53939
#
# ----TAIL ----  longitude  yearbuilt  numberofbuildings  numberoffloors
# 3371          -122.31154       1990                1.0               1  \
# 3372          -122.32283       2004                1.0               1
# 3373          -122.35784       1974                1.0               1
# 3374          -122.32431       1989                1.0               1
# 3375          -122.29536       1938                1.0               1
#
# ----TAIL ----  propertygfaparking  propertygfabuilding  energystarscore
# 3371                            0                12294             46.0  \
# 3372                            0                16000              NaN
# 3373                            0                13157              NaN
# 3374                            0                14101              NaN
# 3375                            0                18258              NaN
#
# ----TAIL ----  siteenergyuse_kbtu  steamuse_kbtu  electricity_kbtu
# 3371                 8.497457e+05              0                 1  \
# 3372                 9.502762e+05              0                 1
# 3373                 5.765898e+06              0                 1
# 3374                 7.194712e+05              0                 1
# 3375                 1.152896e+06              0                 1
#
# ----TAIL ----  naturalgas_kbtu  bool_energystarscore  gfaperfloor
# 3371                         1                     0      12294.0  \
# 3372                         1                     1      16000.0
# 3373                         1                     1      13157.0
# 3374                         1                     1      14101.0
# 3375                         1                     1      18258.0
#
# ----TAIL ----  gfaperbuilding
# 3371                  12294.0
# 3372                  16000.0
# 3373                  13157.0
# 3374                  14101.0
# 3375                  18258.0

# %% [markdown]
# ## 2.2 Structure

# %%
# info :

EDA.first_tour.info(df)
# Out:
# 'shape (3353, 17), memory 0.48MB'
# '---- FLO ----'
#                  cols    types  nan_sum  nan_mean  uniq_sum  uniq_rate  is_sku
# 0            latitude  float64        0      0.00      2858       0.85   False
# 1           longitude  float64        0      0.00      2637       0.79   False
# 2   numberofbuildings  float64        0      0.00        16       0.00   False
# 3     energystarscore  float64      821      0.24       100       0.03   False
# 4  siteenergyuse_kbtu  float64        0      0.00      3353       1.00    True
# 5         gfaperfloor  float64        0      0.00      3259       0.97   False
# 6      gfaperbuilding  float64        0      0.00      3177       0.95   False
# '---- INT ----'
#                    cols  types  nan_sum  nan_mean  uniq_sum  uniq_rate  is_sku
# 0             yearbuilt  int64        0       0.0       113       0.03   False
# 1        numberoffloors  int64        0       0.0        49       0.01   False
# 2    propertygfaparking  int64        0       0.0         2       0.00   False
# 3   propertygfabuilding  int64        0       0.0      3171       0.95   False
# 4         steamuse_kbtu  int64        0       0.0         2       0.00   False
# 5      electricity_kbtu  int64        0       0.0         2       0.00   False
# 6       naturalgas_kbtu  int64        0       0.0         2       0.00   False
# 7  bool_energystarscore  int64        0       0.0         2       0.00   False
# '---- OBJ ----'
#                   cols   types  nan_sum  nan_mean  uniq_sum  uniq_rate  is_sku
# 0  primarypropertytype  object        0       0.0        23       0.01   False
# 1         neighborhood  object        0       0.0        14       0.00   False

# %%
# usefull dtype info :

df.dtypes.value_counts()
# Out:
# int64      8
# float64    7
# object     2
# Name: count, dtype: int64

# %% [markdown]
# ## 2.3 NaN and duplicated

# %%
# # mnso :

# EDA.nan.viz(df)

# %%
# nan rate by columns :

EDA.nan.rate(df)
# Out:
# energystarscore         0.245
# primarypropertytype     0.000
# gfaperfloor             0.000
# bool_energystarscore    0.000
# naturalgas_kbtu         0.000
# electricity_kbtu        0.000
# steamuse_kbtu           0.000
# siteenergyuse_kbtu      0.000
# propertygfabuilding     0.000
# neighborhood            0.000
# propertygfaparking      0.000
# numberoffloors          0.000
# numberofbuildings       0.000
# yearbuilt               0.000
# longitude               0.000
# latitude                0.000
# gfaperbuilding          0.000
# dtype: float64

# %%
# filter on poor columns :

EDA.nan.rate(df, threshold=0.75)
# Out:
# Series([], dtype: float64)

# %%
# same for lines :

EDA.nan.rate(df, axis=1, threshold=0.5)
# Out:
# Series([], dtype: float64)

# %%
# about nan distribution by column :

EDA.nan.rate(df, axis=1, threshold=0.0).value_counts(normalize=True).round(2)
# Out:
# 0.000    0.76
# 0.059    0.24
# Name: proportion, dtype: float64

# %%
# duplicated :

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2.4 Data Inspection

# %%
# describe per type :

EDA.first_tour.describe(df)
# Out:
# ---- FLO ----  latitude  longitude  numberofbuildings  energystarscore
# count           3353.00    3353.00            3353.00          2532.00  \
# mean              47.62    -122.33               1.13            67.91
# std                0.05       0.03               2.11            26.87
# min               47.50    -122.41               1.00             1.00
# 25%               47.60    -122.35               1.00            53.00
# 50%               47.62    -122.33               1.00            75.00
# 75%               47.66    -122.32               1.00            90.00
# max               47.73    -122.22             111.00           100.00
#
# ---- FLO ----  siteenergyuse_kbtu  gfaperfloor  gfaperbuilding
# count                3.353000e+03      3353.00         3353.00
# mean                 5.432676e+06     26236.25        79907.18
# std                  2.166494e+07    166585.34       124694.68
# min                  1.340900e+04       221.70         3636.00
# 25%                  9.353967e+05      8334.83        27140.00
# 50%                  1.813404e+06     13255.00        41834.00
# 75%                  4.233753e+06     24750.50        79957.00
# max                  8.739237e+08   9320156.00      2200000.00
# ---- INT ----  yearbuilt  numberoffloors  propertygfaparking
# count            3353.00         3353.00             3353.00  \
# mean             1968.57            4.73                0.15
# std                33.14            5.51                0.36
# min              1900.00            1.00                0.00
# 25%              1948.00            2.00                0.00
# 50%              1975.00            4.00                0.00
# 75%              1997.00            5.00                0.00
# max              2015.00           99.00                1.00
#
# ---- INT ----  propertygfabuilding  steamuse_kbtu  electricity_kbtu
# count                      3353.00        3353.00           3353.00  \
# mean                      86605.34           0.04              1.00
# std                      207382.71           0.19              0.05
# min                        3636.00           0.00              0.00
# 25%                       27690.00           0.00              1.00
# 50%                       43162.00           0.00              1.00
# 75%                       84385.00           0.00              1.00
# max                     9320156.00           1.00              1.00
#
# ---- INT ----  naturalgas_kbtu  bool_energystarscore
# count                  3353.00               3353.00
# mean                      0.63                  0.24
# std                       0.48                  0.43
# min                       0.00                  0.00
# 25%                       0.00                  0.00
# 50%                       1.00                  0.00
# 75%                       1.00                  0.00
# max                       1.00                  1.00
# ---- OBJ ----   primarypropertytype neighborhood
# count                          3353         3353
# unique                           23           14
# top            low-rise multifamily     downtown
# freq                            983          570

# %%
# # global correlation :

# _ = EDA.study.corr(df)

# %%
# # about distribution :

# EDA.study.skew(df)

# %%
# # pairplot :
# # WARNING : very long computation, avoid if possible else uncomment

# frac = 0.05
# sns.pairplot(df.sample(frac=frac), corner=True)

# %%
# # about outliers :

# EDA.study.outlier(df)

# %%
# # multi colinearity :

# EDA.study.vif(df, scale=True)

# %% [markdown]
# # 2.5 ACP

# %%
# _df = EDA.study.outlier(df, display_=False)
# _df = _df.loc[_df._outlier<0.5]
# _df.shape

# %%
# X = _df.drop(columns="siteenergyuse_kbtu")
# y = _df.siteenergyuse_kbtu

# %%
# pca = EDA.pca(X)

# %%
# _ = pca.variance()

# %%
# _ = pca.pcs()

# %%
# pca.correlation_graph([0, 1])

# %%
# pca.factorial_planes([0, 1])

# %%
# pca.factorial_planes([0, 1], clusters="primarypropertytype")

# %%
# pca.factorial_planes([0, 1, 2])

# %%
# pca.factorial_planes([0, 1, 2], clusters="primarypropertytype")

# %%
# pca.factorial_planes([0, 1, 2], clusters="neighborhood")

# %% [markdown]
# # 3. Modelisation

# %%
## data split

# %%
df
# Out:
#               primarypropertytype           neighborhood  latitude  longitude
# 0                           hotel               downtown  47.61220 -122.33799  \
# 1                           hotel               downtown  47.61317 -122.33393
# 2                           hotel               downtown  47.61393 -122.33810
# 3                           hotel               downtown  47.61412 -122.33664
# 4                           hotel               downtown  47.61375 -122.34047
# ...                           ...                    ...       ...        ...
# 3371  small- and mid-sized office       greater duwamish  47.56722 -122.31154
# 3372                        other               downtown  47.59625 -122.32283
# 3373                        other  magnolia / queen anne  47.63644 -122.35784
# 3374           mixed use property       greater duwamish  47.52832 -122.32431
# 3375           mixed use property       greater duwamish  47.53939 -122.29536
#
#       yearbuilt  numberofbuildings  numberoffloors  propertygfaparking
# 0          1927                1.0              12                   0  \
# 1          1996                1.0              11                   1
# 2          1969                1.0              41                   1
# 3          1926                1.0              10                   0
# 4          1980                1.0              18                   1
# ...         ...                ...             ...                 ...
# 3371       1990                1.0               1                   0
# 3372       2004                1.0               1                   0
# 3373       1974                1.0               1                   0
# 3374       1989                1.0               1                   0
# 3375       1938                1.0               1                   0
#
#       propertygfabuilding  energystarscore  siteenergyuse_kbtu  steamuse_kbtu
# 0                   88434             60.0        7.226362e+06              1  \
# 1                   88502             61.0        8.387933e+06              0
# 2                  759392             43.0        7.258702e+07              1
# 3                   61320             56.0        6.794584e+06              1
# 4                  113580             75.0        1.417261e+07              0
# ...                   ...              ...                 ...            ...
# 3371                12294             46.0        8.497457e+05              0
# 3372                16000              NaN        9.502762e+05              0
# 3373                13157              NaN        5.765898e+06              0
# 3374                14101              NaN        7.194712e+05              0
# 3375                18258              NaN        1.152896e+06              0
#
#       electricity_kbtu  naturalgas_kbtu  bool_energystarscore   gfaperfloor
# 0                    1                1                     0   7369.500000  \
# 1                    1                1                     0   8045.636364
# 2                    1                1                     0  18521.756098
# 3                    1                1                     0   6132.000000
# 4                    1                1                     0   6310.000000
# ...                ...              ...                   ...           ...
# 3371                 1                1                     0  12294.000000
# 3372                 1                1                     1  16000.000000
# 3373                 1                1                     1  13157.000000
# 3374                 1                1                     1  14101.000000
# 3375                 1                1                     1  18258.000000
#
#       gfaperbuilding
# 0            88434.0
# 1            88502.0
# 2           759392.0
# 3            61320.0
# 4           113580.0
# ...              ...
# 3371         12294.0
# 3372         16000.0
# 3373         13157.0
# 3374         14101.0
# 3375         18258.0
#
# [3353 rows x 17 columns]

# %%
data = Data.dataclass(df, "siteenergyuse_kbtu", test_size=0.33)
data
# Out:
# (0, 2246)
# (2246, None)
# (-1, -1)
# (0, 2246)
# (2246, None)
# (-1, -1)
# (0, 2246)
# (2246, None)
# (-1, -1)
# (0, 2246)
# (2246, None)
# (-1, -1)
# (0, 2246)
# (2246, None)
# (-1, -1)
# /home/alex/gargaml/gargaml/data/dataclass.py:38: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._train_tuple = train_tuple
# DataClass(X=3353, train.X=2246, X.train=2246
# X_train_size=2246, X_test_size=1107, X_val_size=0
# y_train_size=2246, y_test_size=1107, y_val_size=0 )

# %%
data.X
# Out:
# (0, 2246)
# (2246, None)
# (-1, -1)
# XX()

# %%
data.y
# Out:
# YY()

# %%
data.train.X
# Out:
#               primarypropertytype           neighborhood  latitude  longitude
# 1945  small- and mid-sized office                central  47.59973 -122.31331  \
# 2252                        other       greater duwamish  47.54089 -122.32323
# 2243         low-rise multifamily                  north  47.69834 -122.32788
# 714          low-rise multifamily  magnolia / queen anne  47.62563 -122.35596
# 1980         low-rise multifamily              southeast  47.52971 -122.26960
# ...                           ...                    ...       ...        ...
# 372                  large office             lake union  47.64882 -122.34905
# 2489                    warehouse       greater duwamish  47.55317 -122.33289
# 546                  large office             lake union  47.64912 -122.34823
# 1947                        other               downtown  47.60791 -122.34140
# 1767                        other                  north  47.72083 -122.29979
#
#       yearbuilt  numberofbuildings  numberoffloors  propertygfaparking
# 1945       1947                1.0               1                   0  \
# 2252       1962                1.0               3                   0
# 2243       1995                1.0               2                   0
# 714        2000                1.0               3                   0
# 1980       2010                1.0               4                   0
# ...         ...                ...             ...                 ...
# 372        1999                1.0               4                   1
# 2489       1964                1.0               1                   0
# 546        2008                1.0               4                   1
# 1947       1982                1.0               5                   1
# 1767       1969                1.0               1                   0
#
#       propertygfabuilding  energystarscore  steamuse_kbtu  electricity_kbtu
# 1945                45068            100.0              0                 1  \
# 2252                36140              NaN              0                 1
# 2243                20261             96.0              0                 1
# 714                 37619             62.0              0                 1
# 1980                88043             82.0              0                 1
# ...                   ...              ...            ...               ...
# 372                140302             89.0              0                 1
# 2489                25000              NaN              0                 1
# 546                113768             73.0              0                 1
# 1947                42360              NaN              0                 1
# 1767                30160              NaN              0                 1
#
#       naturalgas_kbtu  bool_energystarscore   gfaperfloor  gfaperbuilding
# 1945                1                     0  45068.000000         45068.0
# 2252                0                     1  12046.666667         36140.0
# 2243                0                     0  10130.500000         20261.0
# 714                 1                     0  12539.666667         37619.0
# 1980                1                     0  22010.750000         88043.0
# ...               ...                   ...           ...             ...
# 372                 1                     0  35075.500000        140302.0
# 2489                1                     1  25000.000000         25000.0
# 546                 0                     0  28442.000000        113768.0
# 1947                0                     1   8472.000000         42360.0
# 1767                1                     1  30160.000000         30160.0
#
# [2246 rows x 16 columns]

# %%
data.train.y
# Out:
# 1945    2.848573e+05
# 2252    4.653535e+06
# 2243    4.889915e+05
# 714     1.119640e+06
# 1980    2.468322e+06
#             ...
# 372     8.651835e+06
# 2489    1.989104e+06
# 546     8.873485e+06
# 1947    1.527696e+06
# 1767    1.045838e+06
# Name: siteenergyuse_kbtu, Length: 2246, dtype: float64

# %%
token = secrets.token_hex(4)
display(token)

pipe = Pipeline(
    [
        ("imputer", KNNImputer()),
        ("scaler", StandardScaler()),
        ("estimator", RandomForestClassifier()),
    ]
)

param_grid = {
    "scaler": [
        StandardScaler(),
        # QuantileTransformer(n_quantiles=100),
        # Normalizer(),
        "passthrough",
    ],
    "estimator": [
        DummyRegressor(),
        # RandomForestRegressor(),
        # XGBRegressor(),
        LinearRegression(),
    ],
}

grid = GridSearchCV(
    pipe,
    param_grid=param_grid,
    cv=3,
    n_jobs=1,
    verbose=1,
    return_train_score=True,
)

grid
# Out:
# '2c95b007'
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('imputer', KNNImputer()),
#                                        ('scaler', StandardScaler()),
#                                        ('estimator',
#                                         RandomForestClassifier())]),
#              n_jobs=1,
#              param_grid={'estimator': [DummyRegressor(), LinearRegression()],
#                          'scaler': [StandardScaler(), 'passthrough']},
#              return_train_score=True, verbose=1)

# %%
grid.fit(data.X.train.select_dtypes(include=np.number), data.y.train)

results.update(
    grid,
    token=token,
    y_log=0,
    get_dummies=0,
    verbose=0,
).head(5)
# Out:
# (0, 2246)
# (2246, None)
# (-1, -1)
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# /home/alex/gargaml/gargaml/data/dataclass.py:38: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._train_tuple = train_tuple
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('imputer', KNNImputer()),
#                                        ('scaler', StandardScaler()),
#                                        ('estimator',
#                                         RandomForestClassifier())]),
#              n_jobs=1,
#              param_grid={'estimator': [DummyRegressor(), LinearRegression()],
#                          'scaler': [StandardScaler(), 'passthrough']},
#              return_train_score=True, verbose=1)

# %%
# Out:
#    mean_fit_time  std_fit_time     param_estimator      param_scaler
# 2           0.05          0.01  LinearRegression()  StandardScaler()  \
# 3           0.04          0.01  LinearRegression()       passthrough
# 0           0.03          0.01    DummyRegressor()  StandardScaler()
# 1           0.02          0.00    DummyRegressor()       passthrough
#
#                                               params  rank_val_score
# 2  {'estimator': LinearRegression(), 'scaler': St...             2.0  \
# 3  {'estimator': LinearRegression(), 'scaler': 'p...             1.0
# 0  {'estimator': DummyRegressor(), 'scaler': Stan...             3.0
# 1  {'estimator': DummyRegressor(), 'scaler': 'pas...             3.0
#
#                                                 grid
# 2  GridSearchCV(cv=3,\n             estimator=Pip...  \
# 3  GridSearchCV(cv=3,\n             estimator=Pip...
# 0  GridSearchCV(cv=3,\n             estimator=Pip...
# 1  GridSearchCV(cv=3,\n             estimator=Pip...
#
#                                    best_estimator_             datetime
# 2  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48  \
# 3  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48
# 0  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48
# 1  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48
#
#       token cell  model_id  y_log  get_dummies  mean_val_score  std_val_score
# 2  112ab94a       5bad8b6e      0            0            0.56           0.08  \
# 3  112ab94a       5bad8b6e      0            0            0.56           0.08
# 0  112ab94a       5bad8b6e      0            0           -0.01           0.01
# 1  112ab94a       5bad8b6e      0            0           -0.01           0.01
#
#    mean_train_score  std_train_score
# 2              0.66             0.05
# 3              0.66             0.05
# 0              0.00             0.00
# 1              0.00             0.00

# %%
results.res
# Out:
#    mean_fit_time  std_fit_time     param_estimator      param_scaler
# 2         0.0482        0.0061  LinearRegression()  StandardScaler()  \
# 3         0.0377        0.0095  LinearRegression()       passthrough
# 0         0.0312        0.0130    DummyRegressor()  StandardScaler()
# 1         0.0250        0.0007    DummyRegressor()       passthrough
#
#                                               params  rank_val_score
# 2  {'estimator': LinearRegression(), 'scaler': St...             2.0  \
# 3  {'estimator': LinearRegression(), 'scaler': 'p...             1.0
# 0  {'estimator': DummyRegressor(), 'scaler': Stan...             3.0
# 1  {'estimator': DummyRegressor(), 'scaler': 'pas...             3.0
#
#                                                 grid
# 2  GridSearchCV(cv=3,\n             estimator=Pip...  \
# 3  GridSearchCV(cv=3,\n             estimator=Pip...
# 0  GridSearchCV(cv=3,\n             estimator=Pip...
# 1  GridSearchCV(cv=3,\n             estimator=Pip...
#
#                                    best_estimator_             datetime
# 2  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48  \
# 3  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48
# 0  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48
# 1  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48
#
#       token cell  model_id  y_log  get_dummies  mean_val_score  std_val_score
# 2  112ab94a       5bad8b6e      0            0          0.5615         0.0780  \
# 3  112ab94a       5bad8b6e      0            0          0.5615         0.0780
# 0  112ab94a       5bad8b6e      0            0         -0.0061         0.0072
# 1  112ab94a       5bad8b6e      0            0         -0.0061         0.0072
#
#    mean_train_score  std_train_score
# 2            0.6598           0.0518
# 3            0.6598           0.0518
# 0            0.0000           0.0000
# 1            0.0000           0.0000

# %%
results.RES
# Out:
#    mean_fit_time  std_fit_time     param_estimator      param_scaler
# 2         0.0482        0.0061  LinearRegression()  StandardScaler()  \
#
#                                               params  rank_val_score
# 2  {'estimator': LinearRegression(), 'scaler': St...             2.0  \
#
#                                                 grid
# 2  GridSearchCV(cv=3,\n             estimator=Pip...  \
#
#                                    best_estimator_             datetime
# 2  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48  \
#
#       token cell  model_id  y_log  get_dummies  mean_val_score  std_val_score
# 2  112ab94a       5bad8b6e      0            0          0.5615          0.078  \
#
#    mean_train_score  std_train_score
# 2            0.6598           0.0518

# %%
token = secrets.token_hex(4)
display(token)


##############


pipe = Pipeline(
    [
        ("imputer", KNNImputer()),
        ("scaler", StandardScaler()),
        ("estimator", RandomForestClassifier()),
    ]
)


##############


param_grid = {
    "scaler": [
        StandardScaler(),
        QuantileTransformer(n_quantiles=100),
        Normalizer(),
        "passthrough",
    ],
    "estimator": [
        DummyRegressor(),
        RandomForestRegressor(),
        XGBRegressor(),
        LinearRegression(),
    ],
}


##############


log_list = [
    (0, data.y.train),
    (1, np.log1p(data.y.train)),
]
dummies = [
    (0, data.X.train.select_dtypes(include=np.number)),
    (1, pd.get_dummies(data.X.train)),
]


for log, _y in log_list:
    for dummy, _X in dummies:

        logging.warning(log)
        logging.warning(dummy)
        
        grid = GridSearchCV(
            pipe,
            param_grid=param_grid,
            cv=10,
            n_jobs=1,
            verbose=1,
            return_train_score=True,
        )

        grid.fit(_X, _y)

        results.update(
            grid,
            token=token,
            y_log=log,
            get_dummies=dummy,
            verbose=1,
        ).head(5)
# Out:
# 'bbe54d25'
# /home/alex/gargaml/gargaml/data/dataclass.py:38: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._train_tuple = train_tuple
# WARNING:root:0
# WARNING:root:0
# (0, 2246)
# (2246, None)
# (-1, -1)
# (0, 2246)
# (2246, None)
# (-1, -1)
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
#     mean_fit_time  std_fit_time          param_estimator
# 12           0.06          0.00       LinearRegression()  \
# 15           0.07          0.01       LinearRegression()
# 6            1.18          0.01  RandomForestRegressor()
# 5            0.90          0.03  RandomForestRegressor()
# 4            0.87          0.01  RandomForestRegressor()
# 13           0.07          0.01       LinearRegression()
# 14           0.06          0.00       LinearRegression()
# 0            0.05          0.01         DummyRegressor()
# 1            0.06          0.00         DummyRegressor()
# 2            0.05          0.00         DummyRegressor()
#
#                             param_scaler
# 12                      StandardScaler()  \
# 15                           passthrough
# 6                           Normalizer()
# 5   QuantileTransformer(n_quantiles=100)
# 4                       StandardScaler()
# 13  QuantileTransformer(n_quantiles=100)
# 14                          Normalizer()
# 0                       StandardScaler()
# 1   QuantileTransformer(n_quantiles=100)
# 2                           Normalizer()
#
#                                                params  rank_val_score
# 12  {'estimator': LinearRegression(), 'scaler': St...             1.0  \
# 15  {'estimator': LinearRegression(), 'scaler': 'p...             2.0
# 6   {'estimator': RandomForestRegressor(), 'scaler...             3.0
# 5   {'estimator': RandomForestRegressor(), 'scaler...             4.0
# 4   {'estimator': RandomForestRegressor(), 'scaler...             5.0
# 13  {'estimator': LinearRegression(), 'scaler': Qu...             6.0
# 14  {'estimator': LinearRegression(), 'scaler': No...             7.0
# 0   {'estimator': DummyRegressor(), 'scaler': Stan...             8.0
# 1   {'estimator': DummyRegressor(), 'scaler': Quan...             8.0
# 2   {'estimator': DummyRegressor(), 'scaler': Norm...             8.0
#
#                                                  grid
# 12  GridSearchCV(cv=10,\n             estimator=Pi...  \
# 15  GridSearchCV(cv=10,\n             estimator=Pi...
# 6   GridSearchCV(cv=10,\n             estimator=Pi...
# 5   GridSearchCV(cv=10,\n             estimator=Pi...
# 4   GridSearchCV(cv=10,\n             estimator=Pi...
# 13  GridSearchCV(cv=10,\n             estimator=Pi...
# 14  GridSearchCV(cv=10,\n             estimator=Pi...
# 0   GridSearchCV(cv=10,\n             estimator=Pi...
# 1   GridSearchCV(cv=10,\n             estimator=Pi...
# 2   GridSearchCV(cv=10,\n             estimator=Pi...
#
#                                       best_estimator_             datetime
# 12  (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25  \
# 15  (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
# 6   (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
# 5   (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
# 4   (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
# 13  (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
# 14  (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
# 0   (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
# 1   (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
# 2   (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
#
#        token cell  model_id  y_log  get_dummies  mean_val_score
# 12  bfedf07e       e96d031d      0            0            0.49  \
# 15  bfedf07e       e96d031d      0            0            0.49
# 6   bfedf07e       e96d031d      0            0            0.39
# 5   bfedf07e       e96d031d      0            0            0.17
# 4   bfedf07e       e96d031d      0            0            0.12
# 13  bfedf07e       e96d031d      0            0            0.03
# 14  bfedf07e       e96d031d      0            0            0.01
# 0   bfedf07e       e96d031d      0            0           -0.01
# 1   bfedf07e       e96d031d      0            0           -0.01
# 2   bfedf07e       e96d031d      0            0           -0.01
#
#     std_val_score  mean_train_score  std_train_score
# 12           0.48              0.65             0.04
# 15           0.48              0.65             0.04
# 6            0.46              0.94             0.01
# 5            0.93              0.92             0.01
# 4            1.02              0.92             0.01
# 13           0.30              0.24             0.02
# 14           0.49              0.33             0.02
# 0            0.02              0.00             0.00
# 1            0.02              0.00             0.00
# 2            0.02              0.00             0.00
# WARNING:root:0
# WARNING:root:1
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
#     mean_fit_time  std_fit_time
# 12           0.11          0.01  \
# 15           0.11          0.01
# 6            1.90          0.02
# 4            1.44          0.04
# 10           0.30          0.01
# 13           0.14          0.01
# 7            1.38          0.01
# 5            1.41          0.01
# 8            0.29          0.01
# 11           0.28          0.01
#
#                                       param_estimator
# 12                                 LinearRegression()  \
# 15                                 LinearRegression()
# 6                             RandomForestRegressor()
# 4                             RandomForestRegressor()
# 10  XGBRegressor(base_score=None, booster=None, ca...
# 13                                 LinearRegression()
# 7                             RandomForestRegressor()
# 5                             RandomForestRegressor()
# 8   XGBRegressor(base_score=None, booster=None, ca...
# 11  XGBRegressor(base_score=None, booster=None, ca...
#
#                             param_scaler
# 12                      StandardScaler()  \
# 15                           passthrough
# 6                           Normalizer()
# 4                       StandardScaler()
# 10                          Normalizer()
# 13  QuantileTransformer(n_quantiles=100)
# 7                            passthrough
# 5   QuantileTransformer(n_quantiles=100)
# 8                       StandardScaler()
# 11                           passthrough
#
#                                                params  rank_val_score
# 12  {'estimator': LinearRegression(), 'scaler': St...             2.0  \
# 15  {'estimator': LinearRegression(), 'scaler': 'p...             1.0
# 6   {'estimator': RandomForestRegressor(), 'scaler...             3.0
# 4   {'estimator': RandomForestRegressor(), 'scaler...             4.0
# 10  {'estimator': XGBRegressor(base_score=None, bo...             5.0
# 13  {'estimator': LinearRegression(), 'scaler': Qu...             6.0
# 7   {'estimator': RandomForestRegressor(), 'scaler...             7.0
# 5   {'estimator': RandomForestRegressor(), 'scaler...             8.0
# 8   {'estimator': XGBRegressor(base_score=None, bo...             9.0
# 11  {'estimator': XGBRegressor(base_score=None, bo...            10.0
#
#                                                  grid
# 12  GridSearchCV(cv=10,\n             estimator=Pi...  \
# 15  GridSearchCV(cv=10,\n             estimator=Pi...
# 6   GridSearchCV(cv=10,\n             estimator=Pi...
# 4   GridSearchCV(cv=10,\n             estimator=Pi...
# 10  GridSearchCV(cv=10,\n             estimator=Pi...
# 13  GridSearchCV(cv=10,\n             estimator=Pi...
# 7   GridSearchCV(cv=10,\n             estimator=Pi...
# 5   GridSearchCV(cv=10,\n             estimator=Pi...
# 8   GridSearchCV(cv=10,\n             estimator=Pi...
# 11  GridSearchCV(cv=10,\n             estimator=Pi...
#
#                                     best_estimator_             datetime
# 12  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13  \
# 15  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 6   (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 4   (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 10  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 13  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 7   (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 5   (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 8   (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 11  (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
#
#        token cell  model_id  y_log  get_dummies  mean_val_score
# 12  10551142       a1122bc2      0            1            0.62  \
# 15  10551142       a1122bc2      0            1            0.62
# 6   10551142       a1122bc2      0            1            0.55
# 4   10551142       a1122bc2      0            1            0.43
# 10  10551142       a1122bc2      0            1            0.41
# 13  10551142       a1122bc2      0            1            0.41
# 7   10551142       a1122bc2      0            1            0.38
# 5   10551142       a1122bc2      0            1            0.35
# 8   10551142       a1122bc2      0            1            0.16
# 11  10551142       a1122bc2      0            1            0.16
#
#     std_val_score  mean_train_score  std_train_score
# 12           0.31              0.73             0.04
# 15           0.31              0.73             0.04
# 6            0.34              0.95             0.01
# 4            0.70              0.94             0.01
# 10           0.64              1.00             0.00
# 13           0.23              0.53             0.04
# 7            0.76              0.94             0.01
# 5            0.90              0.94             0.01
# 8            1.23              1.00             0.00
# 11           1.23              1.00             0.00
# WARNING:root:1
# WARNING:root:0
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
#     mean_fit_time  std_fit_time
# 4            0.85          0.03  \
# 5            0.81          0.01
# 7            0.80          0.00
# 11           0.27          0.01
# 8            0.28          0.01
# 6            1.00          0.01
# 9            0.28          0.01
# 10           0.28          0.01
# 13           0.07          0.01
# 14           0.06          0.01
#
#                                       param_estimator
# 4                             RandomForestRegressor()  \
# 5                             RandomForestRegressor()
# 7                             RandomForestRegressor()
# 11  XGBRegressor(base_score=None, booster=None, ca...
# 8   XGBRegressor(base_score=None, booster=None, ca...
# 6                             RandomForestRegressor()
# 9   XGBRegressor(base_score=None, booster=None, ca...
# 10  XGBRegressor(base_score=None, booster=None, ca...
# 13                                 LinearRegression()
# 14                                 LinearRegression()
#
#                             param_scaler
# 4                       StandardScaler()  \
# 5   QuantileTransformer(n_quantiles=100)
# 7                            passthrough
# 11                           passthrough
# 8                       StandardScaler()
# 6                           Normalizer()
# 9   QuantileTransformer(n_quantiles=100)
# 10                          Normalizer()
# 13  QuantileTransformer(n_quantiles=100)
# 14                          Normalizer()
#
#                                                params  rank_val_score
# 4   {'estimator': RandomForestRegressor(), 'scaler...             1.0  \
# 5   {'estimator': RandomForestRegressor(), 'scaler...             2.0
# 7   {'estimator': RandomForestRegressor(), 'scaler...             3.0
# 11  {'estimator': XGBRegressor(base_score=None, bo...             4.0
# 8   {'estimator': XGBRegressor(base_score=None, bo...             5.0
# 6   {'estimator': RandomForestRegressor(), 'scaler...             6.0
# 9   {'estimator': XGBRegressor(base_score=None, bo...             7.0
# 10  {'estimator': XGBRegressor(base_score=None, bo...             8.0
# 13  {'estimator': LinearRegression(), 'scaler': Qu...             9.0
# 14  {'estimator': LinearRegression(), 'scaler': No...            10.0
#
#                                                  grid
# 4   GridSearchCV(cv=10,\n             estimator=Pi...  \
# 5   GridSearchCV(cv=10,\n             estimator=Pi...
# 7   GridSearchCV(cv=10,\n             estimator=Pi...
# 11  GridSearchCV(cv=10,\n             estimator=Pi...
# 8   GridSearchCV(cv=10,\n             estimator=Pi...
# 6   GridSearchCV(cv=10,\n             estimator=Pi...
# 9   GridSearchCV(cv=10,\n             estimator=Pi...
# 10  GridSearchCV(cv=10,\n             estimator=Pi...
# 13  GridSearchCV(cv=10,\n             estimator=Pi...
# 14  GridSearchCV(cv=10,\n             estimator=Pi...
#
#                                       best_estimator_             datetime
# 4   (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21  \
# 5   (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 7   (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 11  (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 8   (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 6   (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 9   (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 10  (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 13  (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 14  (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
#
#        token cell  model_id  y_log  get_dummies  mean_val_score
# 4   8eee30a9       1c6c1212      1            0            0.71  \
# 5   8eee30a9       1c6c1212      1            0            0.71
# 7   8eee30a9       1c6c1212      1            0            0.71
# 11  8eee30a9       1c6c1212      1            0            0.69
# 8   8eee30a9       1c6c1212      1            0            0.69
# 6   8eee30a9       1c6c1212      1            0            0.69
# 9   8eee30a9       1c6c1212      1            0            0.69
# 10  8eee30a9       1c6c1212      1            0            0.67
# 13  8eee30a9       1c6c1212      1            0            0.66
# 14  8eee30a9       1c6c1212      1            0            0.62
#
#     std_val_score  mean_train_score  std_train_score
# 4            0.04              0.96              0.0
# 5            0.04              0.96              0.0
# 7            0.04              0.96              0.0
# 11           0.04              0.99              0.0
# 8            0.04              0.99              0.0
# 6            0.04              0.96              0.0
# 9            0.04              0.99              0.0
# 10           0.04              0.97              0.0
# 13           0.03              0.66              0.0
# 14           0.03              0.63              0.0
# WARNING:root:1
# WARNING:root:1
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
#     mean_fit_time  std_fit_time
# 11           0.30          0.01  \
# 8            0.30          0.02
# 9            0.30          0.01
# 4            1.17          0.02
# 7            1.14          0.00
# 10           0.33          0.01
# 5            1.16          0.01
# 6            1.54          0.01
# 13           0.16          0.01
# 15           0.15          0.02
#
#                                       param_estimator
# 11  XGBRegressor(base_score=None, booster=None, ca...  \
# 8   XGBRegressor(base_score=None, booster=None, ca...
# 9   XGBRegressor(base_score=None, booster=None, ca...
# 4                             RandomForestRegressor()
# 7                             RandomForestRegressor()
# 10  XGBRegressor(base_score=None, booster=None, ca...
# 5                             RandomForestRegressor()
# 6                             RandomForestRegressor()
# 13                                 LinearRegression()
# 15                                 LinearRegression()
#
#                             param_scaler
# 11                           passthrough  \
# 8                       StandardScaler()
# 9   QuantileTransformer(n_quantiles=100)
# 4                       StandardScaler()
# 7                            passthrough
# 10                          Normalizer()
# 5   QuantileTransformer(n_quantiles=100)
# 6                           Normalizer()
# 13  QuantileTransformer(n_quantiles=100)
# 15                           passthrough
#
#                                                params  rank_val_score
# 11  {'estimator': XGBRegressor(base_score=None, bo...             1.0  \
# 8   {'estimator': XGBRegressor(base_score=None, bo...             2.0
# 9   {'estimator': XGBRegressor(base_score=None, bo...             3.0
# 4   {'estimator': RandomForestRegressor(), 'scaler...             5.0
# 7   {'estimator': RandomForestRegressor(), 'scaler...             4.0
# 10  {'estimator': XGBRegressor(base_score=None, bo...             6.0
# 5   {'estimator': RandomForestRegressor(), 'scaler...             7.0
# 6   {'estimator': RandomForestRegressor(), 'scaler...             8.0
# 13  {'estimator': LinearRegression(), 'scaler': Qu...             9.0
# 15  {'estimator': LinearRegression(), 'scaler': 'p...            10.0
#
#                                                  grid
# 11  GridSearchCV(cv=10,\n             estimator=Pi...  \
# 8   GridSearchCV(cv=10,\n             estimator=Pi...
# 9   GridSearchCV(cv=10,\n             estimator=Pi...
# 4   GridSearchCV(cv=10,\n             estimator=Pi...
# 7   GridSearchCV(cv=10,\n             estimator=Pi...
# 10  GridSearchCV(cv=10,\n             estimator=Pi...
# 5   GridSearchCV(cv=10,\n             estimator=Pi...
# 6   GridSearchCV(cv=10,\n             estimator=Pi...
# 13  GridSearchCV(cv=10,\n             estimator=Pi...
# 15  GridSearchCV(cv=10,\n             estimator=Pi...
#
#                                       best_estimator_             datetime
# 11  (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04  \
# 8   (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
# 9   (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
# 4   (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
# 7   (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
# 10  (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
# 5   (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
# 6   (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
# 13  (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
# 15  (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04
#
#        token cell  model_id  y_log  get_dummies  mean_val_score
# 11  d2892e19       a15a8590      1            1            0.80  \
# 8   d2892e19       a15a8590      1            1            0.80
# 9   d2892e19       a15a8590      1            1            0.80
# 4   d2892e19       a15a8590      1            1            0.78
# 7   d2892e19       a15a8590      1            1            0.78
# 10  d2892e19       a15a8590      1            1            0.78
# 5   d2892e19       a15a8590      1            1            0.78
# 6   d2892e19       a15a8590      1            1            0.77
# 13  d2892e19       a15a8590      1            1            0.76
# 15  d2892e19       a15a8590      1            1            0.67
#
#     std_val_score  mean_train_score  std_train_score
# 11           0.03              0.99             0.00
# 8            0.03              0.99             0.00
# 9            0.03              0.99             0.00
# 4            0.03              0.97             0.00
# 7            0.03              0.97             0.00
# 10           0.04              0.98             0.00
# 5            0.03              0.97             0.00
# 6            0.04              0.97             0.00
# 13           0.04              0.77             0.00
# 15           0.06              0.71             0.01

# %%
results.RES
# Out:
#    mean_fit_time  std_fit_time
# 9         0.3036        0.0132  \
# 0         0.8546        0.0259
# 1         0.1096        0.0055
# 2         0.1088        0.0099
# 3         0.0482        0.0061
# 4         0.0280        0.0014
# 5         0.0309        0.0015
# 6         0.0285        0.0006
# 7         0.0639        0.0091
# 8         0.0591        0.0037
#
#                                      param_estimator      param_scaler
# 9  XGBRegressor(base_score=None, booster=None, ca...       passthrough  \
# 0                            RandomForestRegressor()  StandardScaler()
# 1                                 LinearRegression()  StandardScaler()
# 2                                 LinearRegression()  StandardScaler()
# 3                                 LinearRegression()  StandardScaler()
# 4                                 LinearRegression()  StandardScaler()
# 5                                 LinearRegression()  StandardScaler()
# 6                                 LinearRegression()  StandardScaler()
# 7                                 LinearRegression()  StandardScaler()
# 8                                 LinearRegression()  StandardScaler()
#
#                                               params  rank_val_score
# 9  {'estimator': XGBRegressor(base_score=None, bo...             1.0  \
# 0  {'estimator': RandomForestRegressor(), 'scaler...             1.0
# 1  {'estimator': LinearRegression(), 'scaler': St...             2.0
# 2  {'estimator': LinearRegression(), 'scaler': St...             2.0
# 3  {'estimator': LinearRegression(), 'scaler': St...             2.0
# 4  {'estimator': LinearRegression(), 'scaler': St...             2.0
# 5  {'estimator': LinearRegression(), 'scaler': St...             2.0
# 6  {'estimator': LinearRegression(), 'scaler': St...             1.0
# 7  {'estimator': LinearRegression(), 'scaler': St...             1.0
# 8  {'estimator': LinearRegression(), 'scaler': St...             1.0
#
#                                                 grid
# 9  GridSearchCV(cv=10,\n             estimator=Pi...  \
# 0  GridSearchCV(cv=10,\n             estimator=Pi...
# 1  GridSearchCV(cv=10,\n             estimator=Pi...
# 2  GridSearchCV(cv=10,\n             estimator=Pi...
# 3  GridSearchCV(cv=3,\n             estimator=Pip...
# 4  GridSearchCV(cv=3,\n             estimator=Pip...
# 5  GridSearchCV(cv=3,\n             estimator=Pip...
# 6  GridSearchCV(cv=3,\n             estimator=Pip...
# 7  GridSearchCV(cv=10,\n             estimator=Pi...
# 8  GridSearchCV(cv=10,\n             estimator=Pi...
#
#                                      best_estimator_             datetime
# 9  (KNNImputer(), passthrough, XGBRegressor(base_...  2023-05-02 13:08:04  \
# 0  (KNNImputer(), StandardScaler(), (DecisionTree...  2023-05-02 13:06:21
# 1    (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:38:58
# 2    (KNNImputer(), passthrough, LinearRegression())  2023-05-02 13:05:13
# 3    (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:12:48
# 4    (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:24:16
# 5    (KNNImputer(), passthrough, LinearRegression())  2023-05-02 12:25:04
# 6  (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 12:25:05
# 7  (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 12:37:10
# 8  (KNNImputer(), StandardScaler(), LinearRegress...  2023-05-02 13:03:25
#
#       token  ...  model_id y_log  get_dummies  mean_val_score  std_val_score
# 9  d2892e19  ...  a15a8590     1            1          0.7982         0.0287  \
# 0  8eee30a9  ...  1c6c1212     1            0          0.7101         0.0360
# 1  fa3b4b13  ...  d565aa95     0            1          0.6197         0.3137
# 2  10551142  ...  a1122bc2     0            1          0.6197         0.3137
# 3  112ab94a  ...  5bad8b6e     0            0          0.5615         0.0780
# 4  439ba5d0  ...  16a41809     1            0          0.5615         0.0780
# 5  67203a3f  ...  ff4d2f08     0            0          0.5615         0.0780
# 6  e37c90a2  ...  f1dba282     1            1          0.5504         0.0026
# 7  aa0b554b  ...  3878ea3e     0            0          0.4921         0.4788
# 8  bfedf07e  ...  e96d031d     0            0          0.4921         0.4788
#
#    mean_train_score  std_train_score       run       exp                 date
# 9            0.9879           0.0011       NaN       NaN                  NaN
# 0            0.9597           0.0009       NaN       NaN                  NaN
# 1            0.7344           0.0372       NaN       NaN                  NaN
# 2            0.7344           0.0372       NaN       NaN                  NaN
# 3            0.6598           0.0518  32f5a199  9f7d9144  2023-05-02 12:11:17
# 4            0.6598           0.0518       NaN       NaN                  NaN
# 5            0.6598           0.0518       NaN       NaN                  NaN
# 6            0.5800           0.0045       NaN       NaN                  NaN
# 7            0.6534           0.0386       NaN       NaN                  NaN
# 8            0.6534           0.0386       NaN       NaN                  NaN
#
# [10 rows x 21 columns]

# %%
# Out:
#                                             best_estimator_  mean_val_score
# model_id
# a15a8590  (KNNImputer(), passthrough, XGBRegressor(base_...          0.7982
# 1c6c1212  (KNNImputer(), StandardScaler(), (DecisionTree...          0.7101
# a1122bc2    (KNNImputer(), passthrough, LinearRegression())          0.6197
# d565aa95    (KNNImputer(), passthrough, LinearRegression())          0.6197
# 16a41809    (KNNImputer(), passthrough, LinearRegression())          0.5615
# 5bad8b6e    (KNNImputer(), passthrough, LinearRegression())          0.5615
# ff4d2f08    (KNNImputer(), passthrough, LinearRegression())          0.5615
# f1dba282  (KNNImputer(), StandardScaler(), LinearRegress...          0.5504
# 3878ea3e  (KNNImputer(), StandardScaler(), LinearRegress...          0.4921
# e96d031d  (KNNImputer(), StandardScaler(), LinearRegress...          0.4921

# %%
# Out:
# 0
# Pipeline(steps=[('imputer', KNNImputer()), ('scaler', 'passthrough'),
#                 ('estimator', LinearRegression())])
